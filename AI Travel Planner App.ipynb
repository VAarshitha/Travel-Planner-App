# %%
pip install langchain google-generativeai streamlit
# Out:
# Collecting langchain
#   Downloading langchain-0.3.20-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: google-generativeai in c:\users\varsh\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: streamlit in c:\users\varsh\anaconda3\lib\site-packages (1.37.1)
# Collecting langchain-core<1.0.0,>=0.3.41 (from langchain)
#   Downloading langchain_core-0.3.43-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.13-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\varsh\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.15-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\varsh\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\varsh\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\varsh\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\varsh\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\varsh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading langchain-0.3.20-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 465.6 kB/s eta 0:00:02
#    ------------------------------- -------- 0.8/1.0 MB 568.6 kB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 568.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 599.5 kB/s eta 0:00:00
# Downloading langchain_core-0.3.43-py3-none-any.whl (415 kB)
# Downloading langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Downloading langsmith-0.3.13-py3-none-any.whl (339 kB)
# Downloading orjson-3.10.15-cp312-cp312-win_amd64.whl (133 kB)
# Installing collected packages: orjson, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed langchain-0.3.20 langchain-core-0.3.43 langchain-text-splitters-0.3.6 langsmith-0.3.13 orjson-3.10.15
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.19-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.43)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.13)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Downloading langchain_community-0.3.19-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 299.6 kB/s eta 0:00:07
#    ------------ --------------------------- 0.8/2.5 MB 409.3 kB/s eta 0:00:05
#    ------------ --------------------------- 0.8/2.5 MB 409.3 kB/s eta 0:00:05
#    ------------ --------------------------- 0.8/2.5 MB 409.3 kB/s eta 0:00:05
#    ---------------- ----------------------- 1.0/2.5 MB 437.6 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.0/2.5 MB 437.6 kB/s eta 0:00:04
#    -------------------- ------------------- 1.3/2.5 MB 450.4 kB/s eta 0:00:03
#    -------------------- ------------------- 1.3/2.5 MB 450.4 kB/s eta 0:00:03
#    ------------------------ --------------- 1.6/2.5 MB 479.4 kB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.5 MB 479.4 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.8/2.5 MB 500.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.8/2.5 MB 500.8 kB/s eta 0:00:02
#    --------------------------------- ------ 2.1/2.5 MB 521.9 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 521.9 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 536.9 kB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 546.1 kB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, marshmallow, httpx-sse, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.19 marshmallow-3.26.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\varsh\anaconda3\lib\site-packages (0.3.19)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.43)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
pip install langchain google-generativeai streamlit
# Out:
# Requirement already satisfied: langchain in c:\users\varsh\anaconda3\lib\site-packages (0.3.20)
# Requirement already satisfied: google-generativeai in c:\users\varsh\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: streamlit in c:\users\varsh\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (0.3.43)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (0.3.13)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\varsh\anaconda3\lib\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\varsh\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\varsh\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\varsh\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varsh\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\varsh\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\varsh\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\varsh\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\varsh\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\varsh\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\varsh\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\varsh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.0.11-py3-none-any.whl.metadata (3.6 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.16 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.16-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.43)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (2.8.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.3.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.20.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.2.3)
# Downloading langchain_google_genai-2.0.11-py3-none-any.whl (39 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.16-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 699.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 699.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 699.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 699.0 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 500.8 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 500.8 kB/s eta 0:00:02
#    ------------------------------ --------- 1.0/1.4 MB 503.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 503.2 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 541.2 kB/s eta 0:00:00
# Installing collected packages: filetype, google-ai-generativelanguage, langchain-google-genai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.6.16 langchain-google-genai-2.0.11
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.16 which is incompatible.

# %%
pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\varsh\anaconda3\lib\site-packages (0.3.19)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.43)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\varsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\varsh\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\varsh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\varsh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\varsh\anaconda3\lib\site-packages (2.0.11)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.16 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (0.6.16)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.43)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (2.8.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.3.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.20.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\varsh\anaconda3\python.exe

# %%
# !pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\varsh\anaconda3\lib\site-packages (2.0.11)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.16 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (0.6.16)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.43)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-google-genai) (2.8.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.3.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\varsh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\varsh\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.20.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\varsh\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\varsh\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\varsh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\varsh\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in c:\users\varsh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\varsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.2.3)

# %%
import streamlit as st
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
import time
import random
import re

# %%
import os
import streamlit as st
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
def load_api_key(file_path):
    with open(file_path) as f:
        for line in f:
            # Skip empty lines or invalid format
            if '=' not in line.strip():
                continue
            key, value = line.strip().split('=', 1)
            if key == 'GEMINI_API_KEY':
                return value
    return None

# %%
st.set_page_config(page_title="AI Travel Planner", page_icon="✈️", layout="wide")
st.title("🌍 AI Travel Planner ✈️")
st.write("Plan your trip with cost estimates, travel details, and food recommendations!")


col1, col2 = st.columns(2)
with col1:
    source = st.text_input("📍 Enter Source Location:", help="Start typing and select a location")
with col2:
    destination = st.text_input("📍 Enter Destination:", help="Start typing and select a location")

budget = st.number_input("💰 Budget (in your currency):", min_value=0, step=100)
travel_time = st.selectbox("⏰ Preferred Travel Time:", ["🌅 Morning", "🌞 Afternoon", "🌆 Evening", "🌙 Night", "Anytime"])
num_travelers = st.number_input("👥 Number of Travelers:", min_value=1, step=1)
preferred_mode = st.multiselect("🚗 Preferred Mode of Transport:", ["🏍️ Bike", "🚖 Cab", "🚌 Bus", "🚆 Train", "✈️ Flight", "Any"])

def clean_markdown(text):
    """Remove markdown formatting like ** for bold"""
    # Remove bold formatting
    text = re.sub(r'\*\*(.*?)\*\*', r'\1', text)
    # Remove other markdown if needed
    text = re.sub(r'\*(.*?)\*', r'\1', text)  # Remove italics
    return text

def format_travel_option(option_text):
    """Clean and format a travel option for display"""
    cleaned_text = clean_markdown(option_text)
    # Make sure there's content in the cleaned text
    if cleaned_text.strip():
        parts = cleaned_text.split(':')
        if len(parts) > 1:
            return parts[0], ': '.join(parts[1:])
        return cleaned_text, ""
    return "Travel Option", "Details not available"

if st.button("🛫 Plan My Trip"):
    if source and destination:
        with st.spinner("🔄 Fetching travel options and food recommendations...."):
            time.sleep(2)  # Simulating loading time

            chat_template = ChatPromptTemplate(messages=[
                ("system", """You are an AI-Powered Travel Planner. Provide travel options (bike, cab, bus, train, flight)
                including estimated cost, travel time, distance, and food recommendations along the way.
                Format each option with a clear title followed by details. Do not use markdown formatting like bold (**) 
                in your response."""),
                ("human", """
                Find travel options from {source} to {destination}.
                Budget: {budget}, Travel Time: {travel_time},
                Number of Travelers: {num_travelers}, Preferred Modes: {preferred_mode}.
                """)
            ])

            chat_model = ChatGoogleGenerativeAI(api_key=GEMINI_API_KEY, model="gemini-2.0-flash-exp")
            parser = StrOutputParser()
            chain = chat_template | chat_model | parser

            raw_input = {
                "source": source,
                "destination": destination,
                "budget": budget,
                "travel_time": travel_time,
                "num_travelers": num_travelers,
                "preferred_mode": ", ".join(preferred_mode) if preferred_mode else "Any"
            }
            response = chain.invoke(raw_input)
            
            # Clean the response
            response = clean_markdown(response)

            st.success("✅ Travel Options:")
            
            # Split the response by newlines, but filter out empty lines
            travel_modes = [line for line in response.split("\n") if line.strip()]
            
            for mode in travel_modes:
                # Skip lines that don't have enough content
                if len(mode.strip()) < 5:
                    continue
                    
                title, details = format_travel_option(mode)
                
                with st.expander(f"📌 {title}"):
                    if details:
                        st.markdown(details)
                    else:
                        st.markdown(title)  # If no details, just show the title
                    st.progress(random.uniform(0.5, 1)) 

            # Food recommendations section
            st.subheader("🍔 Recommended Food on the Route")
            sample_foods = ["🍕 Pizza", "🍛 Biryani", "🌮 Tacos", "🍜 Noodles", "🥗 Salad"]
            st.write("Try these delicacies during your trip:")
            st.markdown(" - " + "\n - ".join(random.sample(sample_foods, 3)))
    else:
        st.warning("⚠️ Please enter both source and destination locations.")
